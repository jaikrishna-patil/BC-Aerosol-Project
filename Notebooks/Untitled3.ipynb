# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import numpy as np


from sklearn.metrics import mean_squared_error
from sklearn.kernel_ridge import KernelRidge
from sklearn.metrics import mean_absolute_error, max_error, mean_absolute_percentage_error

import math

from sklearn.preprocessing import PowerTransformer
import h5py
from keras.models import load_model

import matplotlib.pyplot as plt
import seaborn as sns

from keras.models import Sequential
from keras.layers import Dense, Input, LeakyReLU
from keras.callbacks import EarlyStopping, ModelCheckpoint, CSVLogger
# Out:
# 2022-11-04 10:31:52.858089: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-04 10:31:52.858126: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
#Training KRR time

# %%
import time

array_time=[]
for i in range(0,10):
    
    initial_time= time.time()
    
    import pandas as pd
    from sklearn.preprocessing import PowerTransformer
    from sklearn.kernel_ridge import KernelRidge
    
    df = pd.read_excel('data/database_new.xlsx')
    X = df.iloc[:, :8]
    Y = df.iloc[:, 25:28]
    
    pt = PowerTransformer(method='box-cox')
    X_transformed = pt.fit_transform(X+0.00000000001)
    
    regressor = KernelRidge(alpha=0.0001, gamma=0.75, kernel='rbf')
    model = regressor.fit(X_transformed,Y)

    finish_time= time.time()
    time_diff=finish_time-initial_time
    print(time_diff)
    array_time.append(time_diff)
# Out:
# 34.34169840812683
# 33.88922095298767
# 34.28690266609192
# 34.341501235961914
# 33.95083975791931
# 34.33387207984924
# 33.30136227607727
# 33.39165496826172
# 33.949570417404175
# 33.67763113975525

# %%
min(array_time)
# Out:
# 33.30136227607727

# %%
#Training NN time

# %%
import time

array_time=[]
for i in range(0,5):
    initial_time= time.time()
    
    import pandas as pd
    from sklearn.preprocessing import PowerTransformer
    from keras.models import Sequential
    from keras.layers import Dense, Input
    from keras.callbacks import EarlyStopping, ModelCheckpoint
    
    df = pd.read_excel('database_new.xlsx')
    X = df.iloc[:, :8]
    Y = df.iloc[:, 25:28]


    pt = PowerTransformer(method='box-cox')
    X_transformed = pt.fit_transform(X+0.00000000001)
    
    
    model = Sequential()
    model.add(Input(shape=(8,)))
    for j in range(0,8):
        model.add(Dense(512, kernel_initializer='he_normal', activation='relu'))
    model.add(Dense(3, kernel_initializer='he_normal', activation='linear'))

    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

    checkpoint = ModelCheckpoint('whole_data_bm/best_model.hdf5', verbose=1, monitor='val_loss', save_best_only=True,mode='auto')
    es = EarlyStopping(monitor='val_loss', patience=100, verbose=1)
    callback_list = [checkpoint, es]
    history = model.fit(X_transformed, Y, epochs=1000, batch_size=32, validation_split=0.2, callbacks=callback_list)

    finish_time= time.time()
    time_diff=finish_time-initial_time
    print(time_diff)
    array_time.append(time_diff)
# Out:
# Epoch 1/1000
# 460/464 [============================>.] - ETA: 0s - loss: 0.0682 - mean_absolute_error: 0.0622
# Epoch 1: val_loss improved from inf to 0.02302, saving model to whole_data_bm/best_model.hdf5
# 464/464 [==============================] - 5s 9ms/step - loss: 0.0677 - mean_absolute_error: 0.0619 - val_loss: 0.0230 - val_mean_absolute_error: 0.1028
# Epoch 2/1000
# 458/464 [============================>.] - ETA: 0s - loss: 0.0011 - mean_absolute_error: 0.0223
# Epoch 2: val_loss did not improve from 0.02302
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0011 - mean_absolute_error: 0.0223 - val_loss: 0.0241 - val_mean_absolute_error: 0.1130
# Epoch 3/1000
# 459/464 [============================>.] - ETA: 0s - loss: 6.2131e-04 - mean_absolute_error: 0.0173
# Epoch 3: val_loss improved from 0.02302 to 0.01705, saving model to whole_data_bm/best_model.hdf5
# 464/464 [==============================] - 4s 8ms/step - loss: 6.2095e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0170 - val_mean_absolute_error: 0.0889
# Epoch 4/1000
# 463/464 [============================>.] - ETA: 0s - loss: 9.0987e-04 - mean_absolute_error: 0.0196
# Epoch 4: val_loss improved from 0.01705 to 0.01264, saving model to whole_data_bm/best_model.hdf5
# 464/464 [==============================] - 4s 8ms/step - loss: 9.0971e-04 - mean_absolute_error: 0.0196 - val_loss: 0.0126 - val_mean_absolute_error: 0.0742
# Epoch 5/1000
# 459/464 [============================>.] - ETA: 0s - loss: 5.4118e-04 - mean_absolute_error: 0.0155
# Epoch 5: val_loss improved from 0.01264 to 0.00562, saving model to whole_data_bm/best_model.hdf5
# 464/464 [==============================] - 4s 8ms/step - loss: 5.4067e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0056 - val_mean_absolute_error: 0.0512
# Epoch 6/1000
# 462/464 [============================>.] - ETA: 0s - loss: 5.7052e-04 - mean_absolute_error: 0.0158
# Epoch 6: val_loss did not improve from 0.00562
# 464/464 [==============================] - 3s 7ms/step - loss: 5.7026e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0093 - val_mean_absolute_error: 0.0627
# Epoch 7/1000
# 459/464 [============================>.] - ETA: 0s - loss: 5.6697e-04 - mean_absolute_error: 0.0161
# Epoch 7: val_loss did not improve from 0.00562
# 464/464 [==============================] - 4s 8ms/step - loss: 5.6428e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0080 - val_mean_absolute_error: 0.0537
# Epoch 8/1000
# 458/464 [============================>.] - ETA: 0s - loss: 6.7323e-04 - mean_absolute_error: 0.0168
# Epoch 8: val_loss did not improve from 0.00562
# 464/464 [==============================] - 4s 8ms/step - loss: 6.7623e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0128 - val_mean_absolute_error: 0.0585
# Epoch 9/1000
# 461/464 [============================>.] - ETA: 0s - loss: 6.5666e-04 - mean_absolute_error: 0.0169
# Epoch 9: val_loss did not improve from 0.00562
# 464/464 [==============================] - 4s 8ms/step - loss: 6.5824e-04 - mean_absolute_error: 0.0170 - val_loss: 0.0107 - val_mean_absolute_error: 0.0623
# Epoch 10/1000
# 462/464 [============================>.] - ETA: 0s - loss: 6.8486e-04 - mean_absolute_error: 0.0170
# Epoch 10: val_loss did not improve from 0.00562
# 464/464 [==============================] - 4s 8ms/step - loss: 6.8383e-04 - mean_absolute_error: 0.0170 - val_loss: 0.0077 - val_mean_absolute_error: 0.0445
# Epoch 11/1000
# 458/464 [============================>.] - ETA: 0s - loss: 5.5471e-04 - mean_absolute_error: 0.0153
# Epoch 11: val_loss improved from 0.00562 to 0.00507, saving model to whole_data_bm/best_model.hdf5
# 464/464 [==============================] - 4s 8ms/step - loss: 5.5379e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0051 - val_mean_absolute_error: 0.0434
# Epoch 12/1000
# 457/464 [============================>.] - ETA: 0s - loss: 7.1412e-04 - mean_absolute_error: 0.0172
# Epoch 12: val_loss did not improve from 0.00507
# 464/464 [==============================] - 4s 8ms/step - loss: 7.2726e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0127 - val_mean_absolute_error: 0.0659
# Epoch 13/1000
# 461/464 [============================>.] - ETA: 0s - loss: 6.6043e-04 - mean_absolute_error: 0.0167
# Epoch 13: val_loss did not improve from 0.00507
# 464/464 [==============================] - 4s 8ms/step - loss: 6.6595e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0100 - val_mean_absolute_error: 0.0675
# Epoch 14/1000
# 461/464 [============================>.] - ETA: 0s - loss: 9.9882e-04 - mean_absolute_error: 0.0197
# Epoch 14: val_loss did not improve from 0.00507
# 464/464 [==============================] - 4s 8ms/step - loss: 9.9614e-04 - mean_absolute_error: 0.0197 - val_loss: 0.
-04 - mean_absolute_error: 0.0135 - val_loss: 0.0076 - val_mean_absolute_error: 0.0411
# Epoch 26/1000
# 462/464 [============================>.] - ETA: 0s - loss: 8.0003e-04 - mean_absolute_error: 0.0166
# Epoch 26: val_loss did not improve from 0.00474
# 464/464 [==============================] - 4s 8ms/step - loss: 7.9985e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0058 - val_mean_absolute_error: 0.0436
# Epoch 27/1000
# 463/464 [============================>.] - ETA: 0s - loss: 4.4436e-04 - mean_absolute_error: 0.0130
# Epoch 27: val_loss did not improve from 0.00474
# 464/464 [==============================] - 3s 7ms/step - loss: 4.4444e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0082 - val_mean_absolute_error: 0.0478
# Epoch 28/1000
# 463/464 [============================>.] - ETA: 0s - loss: 4.0982e-04 - mean_absolute_error: 0.0126
# Epoch 28: val_loss did not improve from 0.00474
# 464/464 [==============================] - 4s 8ms/step - loss: 4.0987e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0082 - val_mean_absolute_error: 0.0456
# Epoch 29/1000
# 463/464 [============================>.] - ETA: 0s - loss: 3.8799e-04 - mean_absolute_error: 0.0122
# Epoch 29: val_loss improved from 0.00474 to 0.00430, saving model to whole_data_bm/best_model.hdf5
# 464/464 [==============================] - 4s 9ms/step - loss: 3.8789e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0043 - val_mean_absolute_error: 0.0334
# Epoch 30/1000
# 463/464 [============================>.] - ETA: 0s - loss: 3.0909e-04 - mean_absolute_error: 0.0111
# Epoch 30: val_loss did not improve from 0.00430
# 464/464 [==============================] - 5s 10ms/step - loss: 3.0914e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0075 - val_mean_absolute_error: 0.0412
# Epoch 31/1000
# 463/464 [============================>.] - ETA: 0s - loss: 4.6341e-04 - mean_absolute_error: 0.0135
# Epoch 31: val_loss did not improve from 0.00430
# 464/464 [==============================] - 4s 9ms/step - loss: 4.6344e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0045 - val_mean_absolute_error: 0.0382
# Epoch 32/1000
# 459/464 [============================>.] - ETA: 0s - loss: 4.4803e-04 - mean_absolute_error: 0.0134
# Epoch 32: val_loss did not improve from 0.00430
# 464/464 [==============================] - 4s 9ms/step - loss: 4.4617e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0110 - val_mean_absolute_error: 0.0550
# Epoch 33/1000
# 458/464 [============================>.] - ETA: 0s - loss: 3.3489e-04 - mean_absolute_error: 0.0116
# Epoch 33: val_loss did not improve from 0.00430
# 464/464 [==============================] - 4s 9ms/step - loss: 3.3264e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0059 - val_mean_absolute_error: 0.0389
# Epoch 34/1000
# 460/464 [============================>.] - ETA: 0s - loss: 4.0995e-04 - mean_absolute_error: 0.0121
# Epoch 34: val_loss did not improve from 0.00430
# 464/464 [==============================] - 4s 9ms/step - loss: 4.0886e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0069 - val_mean_absolute_error: 0.0384
# Epoch 35/1000
# 460/464 [============================>.] - ETA: 0s - loss: 2.7875e-04 - mean_absolute_error: 0.0105
# Epoch 35: val_loss did not improve from 0.00430
# 464/464 [==============================] - 4s 9ms/step - loss: 2.7771e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0056 - val_mean_absolute_error: 0.0346
# Epoch 36/1000
# 462/464 [============================>.] - ETA: 0s - loss: 3.2830e-04 - mean_absolute_error: 0.0113
# Epoch 36: val_loss did not improve from 0.00430
# 464/464 [==============================] - 5s 10ms/step - loss: 3.2783e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0051 - val_mean_absolute_error: 0.0388
# Epoch 37/1000
# 460/464 [============================>.] - ETA: 0s - loss: 2.9460e-04 - mean_absolute_error: 0.0108
# Epoch 37: val_loss did not improve from 0.00430
# 464/464 [==============================] - 4s 9ms/step - loss: 2.9357e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0054 - val_mean_absolute_error: 0.0356
# Epoch 38/1000
# 458/464 [============================>.] - ETA: 0s - loss: 3.7434e-04 - mean_absolute_error: 0.0120
# Epoch 38: val_loss did not improve from 0.00430
# 464/464 [==============================] - 4s 9ms/step - loss: 3.7322e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0071 - val_mean_absolute_error: 0.0434
# Epoch 39/1000
# 461/464 [============================>.] - ETA: 0s - loss: 2.5735e-04 - mean_absolute_error: 0.0100
# Epoch 39: val_loss did not improve from 0.00430
# 464/464 [==============================] - 4s 9ms/step - loss: 2.5780e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0057 - val_mean_absolute_error: 0.0359
# Epoch 40/1000
# 463/464 [============================>.] - ETA: 0s - loss: 3.8708e-04 - mean_absolute_error: 0.0121
# Epoch 40: val_loss did not improve from 0.00430
# 464/464 [==============================] - 4s 9ms/step - loss: 3.8698e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0051 - val_mean_absolute_error: 0.0376
# Epoch 41/1000
# 464/464 [==============================] - ETA: 0s - loss: 2.6896e-04 - mean_absolute_error: 0.0094
# Epoch 41: val_loss did not improve from 0.00430
# 464/464 [==============================] - 4s 9ms/step - loss: 2.6896e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0065 - val_mean_absolute_error: 0.0424
# Epoch 42/1000
# 463/464 [============================>.] - ETA: 0s - loss: 2.7194e-04 - mean_absolute_error: 0.0103
# Epoch 42: val_loss did not improve from 0.00430
# 464/464 [==============================] - 4s 9ms/step - loss: 2.7192e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0057 - val_mean_absolute_error: 0.0398
# Epoch 43/1000
# 460/464 [============================>.] - ETA: 0s - loss: 2.0831e-04 - mean_absolute_error: 0.0088
# Epoch 43: val_loss did not improve from 0.00430
# 464/464 [==============================] - 5s 10ms/step - loss: 2.0784e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0051 - val_mean_absolute_error: 0.0342
# Epoch 44/1000
# 460/464 [============================>.] - ETA: 0s - loss: 2.5425e-04 - mean_absolute_error: 0.0101
# Epoch 44: val_loss improved from 0.00430 to 0.00429, saving model to whole_data_bm/best_model.hdf5
# 464/464 [==============================] - 4s 9ms/step - loss: 2.5323e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0043 - val_mean_absolute_error: 0.0339
# Epoch 45/1000
# 460/464 [============================>.] - ETA: 0s - loss: 3.1654e-04 - mean_absolute_error: 0.0106
# Epoch 45: val_loss did not improve from 0.00429
# 464/464 [==============================] - 4s 9ms/step - loss: 3.1843e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0056 - val_mean_absolute_error: 0.0384
# Epoch 46/1000
# 459/464 [============================>.] - ETA: 0s - loss: 2.8101e-04 - mean_absolute_error: 0.0104
# Epoch 46: val_loss improved from 0.00429 to 0.00386, saving model to whole_data_bm/best_model.hdf5
# 464/464 [==============================] - 4s 9ms/step - loss: 2.8071e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0039 - val_mean_absolute_error: 0.0335
# Epoch 47/1000
# 459/464 [============================>.] - ETA: 0s - loss: 2.5072e-04 - mean_absolute_error: 0.0098
# Epoch 47: val_loss did not improve from 0.00386
# 464/464 [==============================] - 4s 9ms/step - loss: 2.5017e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0044 - val_mean_absolute_error: 0.0347
# Epoch 48/1000
# 459/464 [============================>.] - ETA: 0s - loss: 2.2652e-04 - mean_absolute_error: 0.0092
# Epoch 48: val_loss did not improve from 0.00386
# 464/464 [==============================] - 4s 8ms/step - loss: 2.2542e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0045 - val_mean_absolute_error: 0.0333
# Epoch 49/1000
# 458/464 [============================>.] - ETA: 0s - loss: 2.2336e-04 - mean_absolute_error: 0.0091
# Epoch 49: val_loss improved from 0.00386 to 0.00309, saving model to whole_data_bm/best_model.hdf5
# 464/464 [==============================] - 4s 8ms/step - loss: 2.2258e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0031 - val_mean_absolute_error: 0.0306
# Epoch 50/1000
# 460/464 [============================>.] - ETA: 0s - loss: 1.8363e-04 - mean_absolute_error: 0.0086
# Epoch 50: val_loss did not improve from 0.00309
# 464/464 [==============================] - 4s 8ms/step - loss: 1.8308e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0053 - val_mean_absolute_error: 0.0388
# Epoch 51/1000
# 463/464 [============================>.] - ETA: 0s - loss: 2.0107e-04 - mean_absolute_error: 0.0088
# Epoch 51: val_loss did not improve from 0.00309
# 464/464 [==============================] - 4s 9ms/step - loss: 2.0103e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0046 - val_mean_absolute_error: 0.0354
# Epoch 52/1000
# 460/464 [============================>.] - ETA: 0s - loss: 2.2280e-04 - mean_absolute_error: 0.0092
# Epoch 52: val_loss did not improve from 0.00309
# 464/464 [==============================] - 4s 9ms/step - loss: 2.2296e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0053 - val_mean_absolute_error: 0.0390
# Epoch 53/1000
# 458/464 [============================>.] - ETA: 0s - loss: 2.1890e-04 - mean_absolute_error: 0.0092
# Epoch 53: val_loss did not improve from 0.00309
# 464/464 [==============================] - 4s 9ms/step - loss: 2.1726e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0047 - val_mean_absolute_error: 0.0350
# Epoch 54/1000
# 463/464 [============================>.] - ETA: 0s - loss: 2.0648e-04 - mean_absolute_error: 0.0083
# Epoch 54: val_loss did not improve from 0.00309
# 464/464 [==============================] - 4s 10ms/step - loss: 2.0655e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0043 - val_mean_absolute_error: 0.0332
# Epoch 55/1000
# 464/464 [==============================] - ETA: 0s - loss: 1.8786e-04 - mean_absolute_error: 0.0084
# Epoch 55: val_loss did not improve from 0.00309
# 464/464 [==============================] - 4s 9ms/step - loss: 1.8786e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0043 - val_mean_absolute_error: 0.0336
# Epoch 56/1000
# 462/464 [============================>.] - ETA: 0s - loss: 1.5518e-04 - mean_absolute_error: 0.0078
# Epoch 56: val_loss did not improve from 0.00309
# 464/464 [==============================] - 4s 9ms/step - loss: 1.5497e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0056 - val_mean_absolute_error: 0.0393
# Epoch 57/1000
# 461/464 [============================>.] - ETA: 0s - loss: 2.0822e-04 - mean_absolute_error: 0.0089
# Epoch 57: val_loss did not improve from 0.00309
# 464/464 [==============================] - 4s 9ms/step - loss: 2.0778e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0053 - val_mean_absolute_error: 0.0385
# Epoch 58/1000
# 462/464 [============================>.] - ETA: 0s - loss: 1.9895e-04 - mean_absolute_error: 0.0085
# Epoch 58: val_loss did not improve from 0.00309
# 464/464 [==============================] - 4s 9ms/step - loss: 1.9872e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0057 - val_mean_absolute_error: 0.0388
# Epoch 59/1000
# 459/464 [============================>.] - ETA: 0s - loss: 1.6251e-04 - mean_absolute_error: 0.0078
# Epoch 59: val_loss did not improve from 0.00309
# 464/464 [==============================] - 4s 9ms/step - loss: 1.6262e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0038 - val_mean_absolute_error: 0.0321
# Epoch 60/1000
# 459/464 [============================>.] - ETA: 0s - loss: 1.8760e-04 - mean_absolute_error: 0.0084
# Epoch 60: val_loss did not improve from 0.00309
# 464/464 [==============================] - 4s 9ms/step - loss: 1.8730e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0050 - val_mean_absolute_error: 0.0379
# Epoch 61/1000
# 462/464 [============================>.] - ETA: 0s - loss: 1.5688e-04 - mean_absolute_error: 0.0076
# Epoch 61: val_loss did not improve from 0.00309
# 464/464 [==============================] - 4s 9ms/step - loss: 1.5707e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0040 - val_mean_absolute_error: 0.0344
# Epoch 62/1000
# 461/464 [============================>.] - ETA: 0s - loss: 1.4046e-04 - mean_absolute_error: 0.0074
# Epoch 62: val_loss did not improve from 0.00309
# 464/464 [==============================] - 4s 9ms/step - loss: 1.4066e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0039 - val_mean_absolute_error: 0.0346
# Epoch 63/1000
# 459/464 [============================>.] - ETA: 0s - loss: 2.0398e-04 - mean_absolute_error: 0.0089
# Epoch 63: val_loss did not improve from 0.00309
# 464/464 [==============================] - 4s 9ms/step - loss: 2.0431e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0046 - val_mean_absolute_error: 0.0375
# Epoch 64/1000
# 463/464 [============================>.] - ETA: 0s - loss: 1.5733e-04 - mean_absolute_error: 0.0077
# Epoch 64: val_loss did not improve from 0.00309
# 464/464 [==============================] - 4s 9ms/step - loss: 1.5732e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0043 - val_mean_absolute_error: 0.0332
# Epoch 65/1000
# 462/464 [============================>.] - ETA: 0s - loss: 1.9351e-04 - mean_absolute_error: 0.0085
# Epoch 65: val_loss did not improve from 0.00309
# 464/464 [==============================] - 4s 9ms/step - loss: 1.9330e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0043 - val_mean_absolute_error: 0.0327
# Epoch 66/1000
# 461/464 [============================>.] - ETA: 0s - loss: 1.3308e-04 - mean_absolute_error: 0.0069
# Epoch 66: val_loss did not improve from 0.00309
# 464/464 [==============================] - 4s 10ms/step - loss: 1.3330e-04 - mean_absolute_error: 0.0069 - val_loss: 0.0065 - val_mean_absolute_error: 0.0412
# Epoch 67/1000
# 463/464 [============================>.] - ETA: 0s - loss: 1.5311e-04 - mean_absolute_error: 0.0077
# Epoch 67: val_loss did not improve from 0.00309
# 464/464 [==============================] - 4s 9ms/step - loss: 1.5313e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0033 - val_mean_absolute_error: 0.0318
# Epoch 68/1000
# 458/464 [============================>.] - ETA: 0s - loss: 1.6893e-04 - mean_absolute_error: 0.0078
# Epoch 68: val_loss did not improve from 0.00309
# 464/464 [==============================] - 4s 9ms/step - loss: 1
-05 - mean_absolute_error: 0.0041 - val_loss: 0.0028 - val_mean_absolute_error: 0.0300
# Epoch 246/1000
# 463/464 [============================>.] - ETA: 0s - loss: 3.4992e-05 - mean_absolute_error: 0.0039
# Epoch 246: val_loss did not improve from 0.00217
# 464/464 [==============================] - 4s 8ms/step - loss: 3.4996e-05 - mean_absolute_error: 0.0039 - val_loss: 0.0027 - val_mean_absolute_error: 0.0294
# Epoch 247/1000
# 464/464 [==============================] - ETA: 0s - loss: 7.7827e-05 - mean_absolute_error: 0.0057
# Epoch 247: val_loss did not improve from 0.00217
# 464/464 [==============================] - 4s 8ms/step - loss: 7.7827e-05 - mean_absolute_error: 0.0057 - val_loss: 0.0033 - val_mean_absolute_error: 0.0323
# Epoch 248/1000
# 463/464 [============================>.] - ETA: 0s - loss: 6.3307e-05 - mean_absolute_error: 0.0048
# Epoch 248: val_loss did not improve from 0.00217
# 464/464 [==============================] - 4s 8ms/step - loss: 6.3293e-05 - mean_absolute_error: 0.0048 - val_loss: 0.0031 - val_mean_absolute_error: 0.0303
# Epoch 249/1000
# 461/464 [============================>.] - ETA: 0s - loss: 5.2563e-05 - mean_absolute_error: 0.0045
# Epoch 249: val_loss did not improve from 0.00217
# 464/464 [==============================] - 4s 8ms/step - loss: 5.2469e-05 - mean_absolute_error: 0.0045 - val_loss: 0.0033 - val_mean_absolute_error: 0.0309
# Epoch 250/1000
# 457/464 [============================>.] - ETA: 0s - loss: 4.1740e-05 - mean_absolute_error: 0.0041
# Epoch 250: val_loss did not improve from 0.00217
# 464/464 [==============================] - 4s 8ms/step - loss: 4.1633e-05 - mean_absolute_error: 0.0041 - val_loss: 0.0033 - val_mean_absolute_error: 0.0308
# Epoch 251/1000
# 461/464 [============================>.] - ETA: 0s - loss: 5.9928e-05 - mean_absolute_error: 0.0049
# Epoch 251: val_loss did not improve from 0.00217
# 464/464 [==============================] - 4s 8ms/step - loss: 5.9877e-05 - mean_absolute_error: 0.0049 - val_loss: 0.0033 - val_mean_absolute_error: 0.0332
# Epoch 252/1000
# 459/464 [============================>.] - ETA: 0s - loss: 7.9054e-05 - mean_absolute_error: 0.0053
# Epoch 252: val_loss did not improve from 0.00217
# 464/464 [==============================] - 4s 8ms/step - loss: 7.8633e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0026 - val_mean_absolute_error: 0.0280
# Epoch 253/1000
# 464/464 [==============================] - ETA: 0s - loss: 4.0647e-05 - mean_absolute_error: 0.0040
# Epoch 253: val_loss did not improve from 0.00217
# 464/464 [==============================] - 4s 8ms/step - loss: 4.0647e-05 - mean_absolute_error: 0.0040 - val_loss: 0.0024 - val_mean_absolute_error: 0.0278
# Epoch 254/1000
# 458/464 [============================>.] - ETA: 0s - loss: 3.5662e-05 - mean_absolute_error: 0.0039
# Epoch 254: val_loss did not improve from 0.00217
# 464/464 [==============================] - 4s 8ms/step - loss: 3.5571e-05 - mean_absolute_error: 0.0039 - val_loss: 0.0028 - val_mean_absolute_error: 0.0291
# Epoch 255/1000
# 357/464 [======================>.......] - ETA: 0s - loss: 5.3944e-05 - mean_absolute_error: 0.0047
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 4>()
#      31 es = EarlyStopping(monitor='val_loss', patience=100, verbose=1)
#      32 callback_list = [checkpoint, es]
# ---> 33 history = model.fit(X_transformed, Y, epochs=1000, batch_size=32, validation_split=0.2, callbacks=callback_list)
#      35 finish_time= time.time()
#      36 time_diff=finish_time-initial_time
#
# File ~/anaconda3/envs/BCA_new/lib/python3.9/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/BCA_new/lib/python3.9/site-packages/keras/engine/training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File ~/anaconda3/envs/BCA_new/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/BCA_new/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/BCA_new/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/anaconda3/envs/BCA_new/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/anaconda3/envs/BCA_new/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/BCA_new/lib/python3.9/site-packages/tensorflow/python/eager/function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File ~/anaconda3/envs/BCA_new/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
min(array_time)
# Out:
# 1770.2540290355682

# %%
# NN prediction time

# %%
import time

array_time=[]
for i in range(0,100):
    initial_time= time.time()
    import pandas as pd
    from sklearn.preprocessing import PowerTransformer
    from keras.models import Sequential
    from keras.layers import Dense, Input
    from keras.callbacks import EarlyStopping, ModelCheckpoint
    import numpy as np

    
    df_testing = pd.read_excel('database_new.xlsx')
    pt = PowerTransformer(method='box-cox')
    
    X_test = df_testing.iloc[:, :8]
    X_test = pt.fit_transform(X_test+0.00000000001)
    
    
    model = load_model('whole_data_bm/best_model.hdf5')
    Y_test = model.predict(X_test)
#     Y_test = scaling_y.inverse_transform(Y_test)
    #print(Y_test)

    # Computing others
    Y_test = pd.DataFrame(data=Y_test, columns=["q_abs", "q_sca", "g"])

    wavelength = df_testing['wavelength']
    fractal_dimension = df_testing['fractal_dimension']
    fraction_of_coating = df_testing['fraction_of_coating']
    primary_particle_size = df_testing['primary_particle_size']
    number_of_primary_particles = df_testing['number_of_primary_particles']
    vol_equi_radius_inner = df_testing['vol_equi_radius_inner']
    vol_equi_radius_outer = df_testing['vol_equi_radius_outer']
    equi_mobility_dia = df_testing['equi_mobility_dia']

    mie_epsilon = np.zeros_like(wavelength) + 2
    length_scale_factor = 2 * math.pi / wavelength

    m_real_bc=np.empty_like(wavelength)
    for i in range(0,len(wavelength)):
        if wavelength[i]==467:
            m_real_bc[i]=1.92
        elif wavelength[i]==530:
            m_real_bc[i]=1.96
        elif wavelength[i]==660:
            m_real_bc[i]=2
        else:
            m_real_bc[i]=np.nan

    m_im_bc = np.empty_like(wavelength)
    for i in range(0, len(wavelength)):
        if wavelength[i] == 467:
            m_im_bc[i] = 0.67
        elif wavelength[i] == 530:
            m_im_bc[i] = 0.65
        elif wavelength[i] == 660:
            m_im_bc[i] = 0.63
        else:
            m_im_bc[i] = np.nan

    m_real_organics = np.empty_like(wavelength)
    for i in range(0, len(wavelength)):
        if wavelength[i] == 467:
            m_real_organics[i] = 1.59
        elif wavelength[i] == 530:
            m_real_organics[i] = 1.47
        elif wavelength[i] == 660:
            m_real_organics[i] = 1.47
        else:
            m_real_organics[i] = np.nan

    m_im_organics = np.empty_like(wavelength)
    for i in range(0, len(wavelength)):
        if wavelength[i] == 467:
            m_im_organics[i] = 0.11
        elif wavelength[i] == 530:
            m_im_organics[i] = 0.04
        elif wavelength[i] == 660:
            m_im_organics[i] = 0
        else:
            m_im_organics[i] = np.nan

    volume_total = (4 * math.pi * (vol_equi_radius_outer ** 3)) / 3
    volume_bc = (4 * math.pi * (vol_equi_radius_inner ** 3)) / 3
    volume_organics = volume_total - volume_bc

    density_bc = np.zeros_like(wavelength) + 1.5 #Check
    density_organics = np.zeros_like(wavelength) + 1.1 #Check

    mass_bc = volume_bc * density_bc * (1 / 1000000000000000000000)
    mass_organics = volume_organics * density_organics * (1 / 1000000000000000000000)
    mass_total = mass_bc + mass_organics
    mr_total_bc = mass_total / mass_bc
    mr_nonbc_bc = mass_organics / mass_bc

    q_abs = Y_test['q_abs']
    q_sca = Y_test['q_sca']
    q_ext = q_abs + q_sca
    g = Y_test['g']
    c_geo = (math.pi) * ((vol_equi_radius_outer) ** 2)
    c_ext = (q_ext * c_geo) / (float(1000000))
    c_abs = q_abs * c_geo / (1000000)
    c_sca = q_sca * c_geo / (1000000)
    ssa = q_sca / q_ext
    mac_total = (c_abs) / (mass_total * 1000000000000)
    mac_bc = c_abs / (mass_bc * (1000000000000))
    mac_organics = c_abs / (mass_organics * (1000000000000))

    final = np.stack((wavelength, fractal_dimension, fraction_of_coating, primary_particle_size,
                      number_of_primary_particles, vol_equi_radius_inner, vol_equi_radius_outer, equi_mobility_dia,
                      mie_epsilon, length_scale_factor, m_real_bc, m_im_bc, m_real_organics, m_im_organics,
                      volume_total, volume_bc, volume_organics, density_bc, density_organics, mass_total, mass_organics,
                      mass_bc, mr_total_bc, mr_nonbc_bc, q_ext, q_abs, q_sca, g, c_geo, c_ext, c_abs, c_sca, ssa,
                      mac_total, mac_bc, mac_organics), axis=1)

    final_dataset = pd.DataFrame(data=final, columns=['wavelength', 'fractal_dimension', 'fraction_of_coating', 'primary_particle_size',
                      'number_of_primary_particles', 'vol_equi_radius_inner', 'vol_equi_radius_outer', 'equi_mobility_dia',
                      'mie_epsilon', 'length_scale_factor', 'm_real_bc', 'm_im_bc', 'm_real_organics', 'm_im_organics',
                      'volume_total', 'volume_bc', 'volume_organics', 'density_bc', 'density_organics', 'mass_total', 'mass_organics',
                      'mass_bc', 'mr_total_bc', 'mr_nonbc_bc', 'q_ext', 'q_abs', 'q_sca', 'g', 'c_geo', 'c_ext', 'c_abs', 'c_sca', 'ssa',
                      'mac_total', 'mac_bc', 'mac_organics'])
    final_dataset.to_csv('..\data\sample_predicted_forward_dataset.csv', index=False)
    finish_time= time.time()
    time_diff=finish_time-initial_time
    print(time_diff)
    array_time.append(time_diff)
    
    #print(Y_test)
# Out:
# 579/579 [==============================] - 3s 4ms/step
# 10.880236864089966
# 579/579 [==============================] - 3s 5ms/step
# 10.178588628768921
# 579/579 [==============================] - 3s 4ms/step
# 10.035953760147095
# 579/579 [==============================] - 3s 4ms/step
# 10.052278518676758
# 579/579 [==============================] - 3s 4ms/step
# 10.281131505966187
# 579/579 [==============================] - 3s 5ms/step
# 10.162027359008789
# 579/579 [==============================] - 3s 4ms/step
# 10.227025747299194
# 579/579 [==============================] - 3s 4ms/step
# 10.428905725479126
# 579/579 [==============================] - 3s 4ms/step
# 10.120203733444214
# 579/579 [==============================] - 3s 4ms/step
# 10.049685955047607
# 579/579 [==============================] - 3s 4ms/step
# 10.29589295387268
# 579/579 [==============================] - 3s 5ms/step
# 10.15614128112793
# 579/579 [==============================] - 3s 4ms/step
# 10.112793684005737
# 579/579 [==============================] - 3s 5ms/step
# 10.311821222305298
# 579/579 [==============================] - 3s 4ms/step
# 10.115382432937622
# 579/579 [==============================] - 3s 4ms/step
# 10.166873216629028
# 579/579 [==============================] - 2s 4ms/step
# 10.368010520935059
# 579/579 [==============================] - 3s 4ms/step
# 10.280587434768677
# 579/579 [==============================] - 3s 4ms/step
# 10.08678650856018
# 579/579 [==============================] - 3s 4ms/step
# 10.108362197875977
# 579/579 [==============================] - 3s 4ms/step
# 10.272065877914429
# 579/579 [==============================] - 3s 4ms/step
# 10.158944606781006
# 579/579 [==============================] - 3s 4ms/step
# 10.019002199172974
# 579/579 [==============================] - 3s 4ms/step
# 10.175936222076416
# 579/579 [==============================] - 3s 4ms/step
# 10.292511701583862
# 579/579 [==============================] - 3s 4ms/step
# 10.0195631980896
# 579/579 [==============================] - 3s 4ms/step
# 10.084517240524292
# 579/579 [==============================] - 3s 4ms/step
# 10.274808883666992
# 579/579 [==============================] - 3s 4ms/step
# 9.976870775222778
# 579/579 [==============================] - 3s 4ms/step
# 10.046077966690063
# 579/579 [==============================] - 2s 4ms/step
# 9.982635259628296
# 579/579 [==============================] - 2s 4ms/step
# 9.790748834609985
# 579/579 [==============================] - 2s 4ms/step
# 9.952898740768433
# 579/579 [==============================] - 3s 4ms/step
# 10.046729326248169
# 579/579 [==============================] - 3s 4ms/step
# 10.20993185043335
# 579/579 [==============================] - 3s 4ms/step
# 10.097405195236206
# 579/579 [==============================] - 2s 4ms/step
# 9.820971965789795
# 579/579 [==============================] - 3s 4ms/step
# 10.230814933776855
# 579/579 [==============================] - 2s 4ms/step
# 9.595715045928955
# 579/579 [==============================] - 2s 4ms/step
# 9.963262796401978
# 579/579 [==============================] - 2s 4ms/step
# 10.11514687538147
# 579/579 [==============================] - 3s 4ms/step
# 10.061750888824463
# 579/579 [==============================] - 3s 4ms/step
# 9.970553398132324
# 579/579 [==============================] - 3s 4ms/step
# 10.062933921813965
# 579/579 [==============================] - 2s 4ms/step
# 10.1265709400177
# 579/579 [==============================] - 2s 4ms/step
# 9.974661588668823
# 579/579 [==============================] - 2s 4ms/step
# 9.945366144180298
# 579/579 [==============================] - 2s 4ms/step
# 10.089900732040405
# 579/579 [==============================] - 3s 4ms/step
# 10.036651134490967
# 579/579 [==============================] - 2s 4ms/step
# 9.933579444885254
# 579/579 [==============================] - 3s 4ms/step
# 10.264881610870361
# 579/579 [==============================] - 3s 4ms/step
# 10.024125099182129

# %%
min_time = min(array_time)
min_time
# Out:
# 9.595715045928955

# %%
min_time/18526
# Out:
# 0.000517959356899976

# %%
#Prediction time for KRR

# %%
import pandas as pd
from sklearn.preprocessing import PowerTransformer
from sklearn.kernel_ridge import KernelRidge

df = pd.read_excel('database_new.xlsx')
X = df.iloc[:, :8]
Y = df.iloc[:, 25:28]

pt = PowerTransformer(method='box-cox')
X_transformed = pt.fit_transform(X+0.00000000001)

regressor = KernelRidge(alpha=0.0001, gamma=0.75, kernel='rbf')
model = regressor.fit(X_transformed,Y)

# %%
import time

array_time=[]
for i in range(0,100):
    initial_time= time.time()
    import pandas as pd
    from sklearn.preprocessing import PowerTransformer
    from sklearn.kernel_ridge import KernelRidge
    
    
    df_testing = pd.read_excel('database_new.xlsx')
    pt = PowerTransformer(method='box-cox')
    
    X_test = df_testing.iloc[:, :8]
    X_test = pt.fit_transform(X_test+0.00000000001)
    
    
    
    Y_test = model.predict(X_test)
#     Y_test = scaling_y.inverse_transform(Y_test)
    #print(Y_test)

    # Computing others
    Y_test = pd.DataFrame(data=Y_test, columns=["q_abs", "q_sca", "g"])

    wavelength = df_testing['wavelength']
    fractal_dimension = df_testing['fractal_dimension']
    fraction_of_coating = df_testing['fraction_of_coating']
    primary_particle_size = df_testing['primary_particle_size']
    number_of_primary_particles = df_testing['number_of_primary_particles']
    vol_equi_radius_inner = df_testing['vol_equi_radius_inner']
    vol_equi_radius_outer = df_testing['vol_equi_radius_outer']
    equi_mobility_dia = df_testing['equi_mobility_dia']

    mie_epsilon = np.zeros_like(wavelength) + 2
    length_scale_factor = 2 * math.pi / wavelength

    m_real_bc=np.empty_like(wavelength)
    for i in range(0,len(wavelength)):
        if wavelength[i]==467:
            m_real_bc[i]=1.92
        elif wavelength[i]==530:
            m_real_bc[i]=1.96
        elif wavelength[i]==660:
            m_real_bc[i]=2
        else:
            m_real_bc[i]=np.nan

    m_im_bc = np.empty_like(wavelength)
    for i in range(0, len(wavelength)):
        if wavelength[i] == 467:
            m_im_bc[i] = 0.67
        elif wavelength[i] == 530:
            m_im_bc[i] = 0.65
        elif wavelength[i] == 660:
            m_im_bc[i] = 0.63
        else:
            m_im_bc[i] = np.nan

    m_real_organics = np.empty_like(wavelength)
    for i in range(0, len(wavelength)):
        if wavelength[i] == 467:
            m_real_organics[i] = 1.59
        elif wavelength[i] == 530:
            m_real_organics[i] = 1.47
        elif wavelength[i] == 660:
            m_real_organics[i] = 1.47
        else:
            m_real_organics[i] = np.nan

    m_im_organics = np.empty_like(wavelength)
    for i in range(0, len(wavelength)):
        if wavelength[i] == 467:
            m_im_organics[i] = 0.11
        elif wavelength[i] == 530:
            m_im_organics[i] = 0.04
        elif wavelength[i] == 660:
            m_im_organics[i] = 0
        else:
            m_im_organics[i] = np.nan

    volume_total = (4 * math.pi * (vol_equi_radius_outer ** 3)) / 3
    volume_bc = (4 * math.pi * (vol_equi_radius_inner ** 3)) / 3
    volume_organics = volume_total - volume_bc

    density_bc = np.zeros_like(wavelength) + 1.5 #Check
    density_organics = np.zeros_like(wavelength) + 1.1 #Check

    mass_bc = volume_bc * density_bc * (1 / 1000000000000000000000)
    mass_organics = volume_organics * density_organics * (1 / 1000000000000000000000)
    mass_total = mass_bc + mass_organics
    mr_total_bc = mass_total / mass_bc
    mr_nonbc_bc = mass_organics / mass_bc

    q_abs = Y_test['q_abs']
    q_sca = Y_test['q_sca']
    q_ext = q_abs + q_sca
    g = Y_test['g']
    c_geo = (math.pi) * ((vol_equi_radius_outer) ** 2)
    c_ext = (q_ext * c_geo) / (float(1000000))
    c_abs = q_abs * c_geo / (1000000)
    c_sca = q_sca * c_geo / (1000000)
    ssa = q_sca / q_ext
    mac_total = (c_abs) / (mass_total * 1000000000000)
    mac_bc = c_abs / (mass_bc * (1000000000000))
    mac_organics = c_abs / (mass_organics * (1000000000000))

    final = np.stack((wavelength, fractal_dimension, fraction_of_coating, primary_particle_size,
                      number_of_primary_particles, vol_equi_radius_inner, vol_equi_radius_outer, equi_mobility_dia,
                      mie_epsilon, length_scale_factor, m_real_bc, m_im_bc, m_real_organics, m_im_organics,
                      volume_total, volume_bc, volume_organics, density_bc, density_organics, mass_total, mass_organics,
                      mass_bc, mr_total_bc, mr_nonbc_bc, q_ext, q_abs, q_sca, g, c_geo, c_ext, c_abs, c_sca, ssa,
                      mac_total, mac_bc, mac_organics), axis=1)

    final_dataset = pd.DataFrame(data=final, columns=['wavelength', 'fractal_dimension', 'fraction_of_coating', 'primary_particle_size',
                      'number_of_primary_particles', 'vol_equi_radius_inner', 'vol_equi_radius_outer', 'equi_mobility_dia',
                      'mie_epsilon', 'length_scale_factor', 'm_real_bc', 'm_im_bc', 'm_real_organics', 'm_im_organics',
                      'volume_total', 'volume_bc', 'volume_organics', 'density_bc', 'density_organics', 'mass_total', 'mass_organics',
                      'mass_bc', 'mr_total_bc', 'mr_nonbc_bc', 'q_ext', 'q_abs', 'q_sca', 'g', 'c_geo', 'c_ext', 'c_abs', 'c_sca', 'ssa',
                      'mac_total', 'mac_bc', 'mac_organics'])
    final_dataset.to_csv('..\data\sample_predicted_KRR_forward_dataset.csv', index=False)
    finish_time= time.time()
    time_diff=finish_time-initial_time
    print(time_diff)
    array_time.append(time_diff)
    
    #print(Y_test)
# Out:
# 12.02573299407959
# 12.2666335105896
# 12.511543035507202
# 11.843337535858154
# 12.180219411849976
# 11.955689668655396
# 12.463340759277344
# 12.23664140701294
# 12.285416841506958
# 12.850793361663818
# 12.390633344650269
# 12.015601396560669
# 11.86967945098877
# 11.833184242248535
# 11.748512268066406
# 11.808793544769287
# 11.724557638168335
# 11.97889518737793
# 13.605550050735474
# 12.928999662399292
# 12.974056720733643
# 12.565818786621094
# 12.846785068511963
# 12.53324580192566
# 11.88088846206665
# 11.610703229904175
# 11.638303518295288
# 12.104576587677002
# 11.616114854812622
# 12.058106899261475
# 12.212485313415527
# 12.121195793151855
# 11.71978759765625
# 12.5917489528656
# 11.758710384368896
# 12.202581405639648
# 13.079184532165527
# 12.06770372390747
# 12.669737577438354
# 12.05860185623169
# 12.09777545928955
# 12.380205154418945
# 12.499988317489624
# 12.454230785369873
# 12.301075458526611
# 13.455131769180298
# 12.224504709243774
# 12.035171031951904
# 12.829692840576172
# 12.720654726028442
# 12.319801568984985
# 11.809705257415771
# 12.036538362503052
# 11.912886619567871
# 12.357763528823853
# 12.652187585830688
# 12.388317346572876
# 12.107987880706787
# 11.944021463394165
# 12.346580505371094
# 12.319340229034424
# 11.993818283081055
# 12.711924314498901
# 12.592339515686035
# 12.425072431564331
# 12.179118156433105
# 11.895794153213501
# 12.421406745910645
# 12.407047271728516
# 12.314501523971558
# 12.302132368087769
# 12.305265665054321
# 12.393706321716309
# 12.20936369895935
# 12.48836874961853
# 12.674580335617065
# 12.909773588180542
# 13.076765537261963
# 12.908577680587769
# 12.666446924209595
# 12.75328254699707
# 12.403436660766602
# 12.311504602432251
# 12.42026400566101
# 12.56530475616455
# 12.759696960449219
# 12.809840202331543
# 14.03642725944519
# 12.796693563461304
# 12.309921741485596
# 12.075524806976318
# 11.98586654663086
# 12.256950855255127
# 13.127823114395142
# 12.83391547203064
# 12.581691265106201
# 12.184031963348389
# 12.532183647155762
# 12.166175603866577
# 12.225373983383179

# %%
min_time = min(array_time)
min_time
# Out:
# 11.610703229904175

# %%
min_time/18526
# Out:
# 0.0006267247776046732
