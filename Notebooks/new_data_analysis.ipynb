# %%
import pandas as pd

# %%
df=pd.read_excel("database_new.xlsx")

# %%
df.head()
# Out:
#    wavelength  fractal_dimension  fraction_of_coating  primary_particle_size  \
# 0         660                1.5                    0                   15.0
# 1         660                1.5                    0                   15.0
# 2         660                1.5                    0                   15.0
# 3         660                1.5                    0                   15.0
# 4         660                1.5                    0                   15.0
#
#    number_of_primary_particles  vol_equi_radius_outer  vol_equi_radius_inner  \
# 0                          1.0              15.000000              15.000000
# 1                          2.0              18.898816              18.898816
# 2                          3.0              21.633744              21.633744
# 3                          4.0              23.811016              23.811016
# 4                          5.0              25.649639              25.649639
#
# ...
